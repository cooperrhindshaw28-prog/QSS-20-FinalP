# %%
# QSS 20 Final Project
# Cooper Hindshaw

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os

print(os.getcwd())
print(os.listdir())

df = pd.read_stata("../dataverse_files/UCT_FINAL_CLEAN.dta")

print("Shape of dataset:")
print(df.shape)

print("\nFirst five rows:")
display(df.head())

# Find treatment-related variables
treatment_vars = [
    col for col in df.columns
    if any(word in col.lower()
           for word in ["treat", "spillover", "control", "large", "lump", "monthly"])]

print("\nTreatment-related variables:")
print(treatment_vars)
# Out:
# /Users/cooper/Documents/GitHub/QSS-20-FinalP/code
# ['03_Replication_Analysis.ipynb', '.DS_Store', '02_initial_vis.ipynb', '01_load_data_analysis.ipynb', '04_Replication_Analysis_v2.ipynb', '.ipynb_checkpoints']
# Shape of dataset:
# (2880, 981)
#
# First five rows:
#       surveyid  femaleres  maleres  village  treat  spillover  purecontrol  \
# 0  106540326.0          0      1.0       74    0.0        1.0          0.0
# 1  106540326.0          1      0.0       74    0.0        1.0          0.0
# 2  106769148.0          0      1.0       55    1.0        0.0          0.0
# 3  106769148.0          1      0.0       55    1.0        0.0          0.0
# 4  106799419.0          0      1.0       71    0.0        1.0          0.0
#
#    control_village  treatXfemalerec  treatXmalerec  ...  m_cesd11  m_cesd12  \
# 0              0.0              0.0            0.0  ...       1.0       2.0
# 1              0.0              0.0            0.0  ...       1.0       2.0
# ...

# %%
# Find asset-related variables
asset_vars = [
    col for col in df.columns
    if any(word in col.lower()
           for word in ["asset", "wealth", "durable", "livestock",
                        "cow", "goat", "land", "roof", "house"])]

print("\nAsset-related variables:")
print(asset_vars)

# Number of unique survey IDs
print("\nNumber of unique survey IDs:")
print(df["surveyid"].nunique())
# Out:
# Asset-related variables:
# ...

# %%
# Look at the main variables for this project
important_vars = df[
    [ "surveyid",
        "treat",
        "asset_total_ppp0",
        "asset_total_ppp1"]]

print("\nMain project variables:")
display(important_vars.head())

# Summary statistics for baseline and follow-up assets
print("\nAsset summary statistics:")
display(
    df[["asset_total_ppp0",
        "asset_total_ppp1"]].describe())
# Out:
# Main project variables:
#       surveyid  treat  asset_total_ppp0  asset_total_ppp1
# 0  106540326.0    0.0        127.781700        240.070389
# 1  106540326.0    0.0        127.781700        240.070389
# 2  106769148.0    1.0        395.460785        665.341370
# 3  106769148.0    1.0        395.460785        665.341370
# 4  106799419.0    0.0        731.324097       1384.297607
# Asset summary statistics:
#        asset_total_ppp0  asset_total_ppp1
# count       2880.000000       2880.000000
# mean         267.174622        536.925171
# std          369.133728        454.425568
# min            0.000000          0.000000
# 25%            0.000000        193.192886
# 50%          165.232559        385.386078
# 75%          368.405304        826.012741
# max         4424.277832       2561.091064
