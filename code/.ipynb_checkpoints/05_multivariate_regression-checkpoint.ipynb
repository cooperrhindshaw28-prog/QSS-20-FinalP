# %%
#MLR
# QSS 20 Final Project
# Cooper Hindshaw

# 05_MLR.ipynb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_stata("../dataverse_files/UCT_FINAL_CLEAN.dta")

df = df.drop_duplicates(subset="surveyid").copy()


# Keep observations with both baseline and follow-up assets
rep = df[
    ["surveyid",
     "treat",
     "asset_total_ppp0",
     "asset_total_ppp1",
    "treatXsmall",
    "treatXlarge"]
    ].dropna().copy()

# Rename variables to make the code easier to read
rep = rep.rename(
    columns={"asset_total_ppp0": "assets_baseline",
             "asset_total_ppp1": "assets_followup"})

for var in [
    "asset_livestock_ppp0",
    "asset_durable_ppp0",
    "asset_ag_ppp0",
    "asset_trans_ppp0",
    "durable_investment0"]:
    print(var)

reader = pd.io.stata.StataReader(
    "../dataverse_files/UCT_FINAL_CLEAN.dta")

labels = reader.variable_labels()

for var in [
    "asset_livestock_ppp0",
    "asset_durable_ppp0",
    "asset_ag_ppp0",
    "asset_trans_ppp0",
    "durable_investment0"]:
    print(var, ":", labels[var])

reader = pd.io.stata.StataReader(
    "../dataverse_files/UCT_FINAL_CLEAN.dta"
)

labels = reader.variable_labels()

for var in df.columns:
    if any(word in var.lower() for word in
           ["large", "small", "amount", "transfer", "lump", "monthly", "size", "asset"]):
        print(var, ":", labels.get(var))

df[["treat", "treatXlarge", "treatXsmall"]].value_counts()

rep["treatment_group"] = np.select(
    [(df["treat"] == 0),(df["treatXsmall"] == 1),(df["treatXlarge"] == 1)],
    ["Control","Small Transfer","Large Transfer"],default="Other")

rep["treatment_group"].value_counts()


rep["productive_assets_baseline"] = (
    df["asset_livestock_ppp0"]
    + df["asset_ag_ppp0"]
    + df["asset_trans_ppp0"])

rep["productive_assets_followup"] = (
    df["asset_livestock_ppp1"]
    + df["asset_ag_ppp1"]
    + df["asset_trans_ppp1"])

rep["productive_assets_change"]= (rep["productive_assets_followup"] - rep["productive_assets_baseline"])
rep.head()
rep["productive_assets_change"].describe()

# Balboni uses log assets.
# log1p allows households with zero assets to remain in the sample.
rep["log_passets_baseline"] = np.log1p(rep["productive_assets_baseline"])
rep["log_passets_followup"] = np.log1p(rep["productive_assets_followup"])

rep["log_passets_change"]= (rep["log_passets_followup"] - rep["log_passets_baseline"])
# Out:
# asset_livestock_ppp0
# asset_durable_ppp0
# asset_ag_ppp0
# asset_trans_ppp0
# durable_investment0
# asset_livestock_ppp0 : Value of livestock (USD)
# asset_durable_ppp0 : Value of durable goods (USD)
# asset_ag_ppp0 : \hspace{0.2cm}Value of agricultural tools (USD)
# asset_trans_ppp0 : \hspace{0.2cm}Value of bike/motorbike (USD)
# durable_investment0 : Durable Investments
# treatXlump : Treatment x Lump sum transfer
# treatXmonthly : Treatment x Monthly transfer
# treatXlarge : Treatment x Large transfer
# treatXsmall : Treatment x Small transfer
# treatXmalerecXlump : Treatment x Male recipient x Lump sum transfer
# treatXmalerecXsmall : Treatment x Male recipient x Small transfer
# treatXlumpXsmall : Treatment x Lump sum transfer x Small transfer
# treatXmalerecXlumpXsmall : Treatment x Male recipient x Lump sum transfer x Small transfer
# treatXmalerecXlarge : Treatment x Male recipient x Large transfer
# treatXlumpXlarge : Treatment x Lump sum transfer x Large transfer
# treatXmalerecXlumpXlarge : Treatment x Male recipient x Lump sum transfer x Large transfer
# treatXmalerecXmonthly : Treatment x Male recipient x Monthly transfer
# treatXmonthlyXsmall : Treatment x Monthly transfer x Small transfer
# treatXmalerecXmonthlyXsmall : Treatment x Male recipient x Monthly transfer x Small transfer
# treatXmonthlyXlarge : Treatment x Monthly transfer x Large transfer
# treatXmalerecXmonthlyXlarge : Treatment x Male recipient x Monthly transfer x Large transfer
# treatXfemalerecXlump : Treatment x Female recipient x Lump sum transfer
# treatXfemalerecXsmall : Treatment x Female recipient x Small transfer
# treatXfemalerecXlumpXsmall : Treatment x Female recipient x Lump sum transfer x Small transfer
# treatXfemalerecXlarge : Treatment x Female recipient x Large transfer
# treatXfemalerecXlumpXlarge : Treatment x Female recipient x Lump sum transfer x Large transfer
# treatXfemalerecXmonthly : Treatment x Female recipient x Monthly transfer
# treatXfemalerecXmonthlyXsmall : Treatment x Female recipient x Monthly transfer x Small transfer
# treatXfemalerecXmonthlyXlarge : Treatment x Female recipient x Monthly transfer x Large transfer
# treatXlargeXmaleres : Treatment x Large transfer x Male respondent
# treatXlargeXfemaleres : Treatment x Large transfer x Female respondent
# treatXsmallXmaleres : Treatment x Small transfer x Male respondent
# treatXsmallXfemaleres : Treatment x small transfer x Female respondent
# treatXlumpXmaleres : Treatment x Lump sum transfer x Male respondent
# treatXlumpXfemaleres : Treatment x Lump sum transfer x Female respondent
# treatXmonthlyXmaleres : Treatment x Monthly transfer x Male respondent
# treatXmonthlyXfemaleres : Treatment x Monthly transfer x Female respondent
# treatXlumpXearly : Treatment x Lump sum transfer x Early payment date
# treatXlumpXlate : Treatment x Lump sum transfer x Late payment date
# lasttransferdate : Date of last transfer payment
# firsttransferdate : Date of first transfer payment
# b_hhsize : Household size
# asset_total_ppp0 : Value of non-land assets (USD)
# asset_total_ppp_full0 : Value of non-land assets (USD) - Full
# asset_total_ppp_miss0 : Value of non-land assets (USD) - Missing
# asset_total_ppp1 : Value of non-land assets (USD)
# asset_lntotal_ppp0 : Value of non-land assets (USD)
# asset_lntotal_ppp_full0 : Value of non-land assets (USD) - Full
# asset_lntotal_ppp_miss0 : Value of non-land assets (USD) - Missing
# asset_lntotal_ppp1 : Value of non-land assets (USD)
# asset_total_noroof_ppp0 : Value of non-land assets excluding roof (USD)
# asset_total_noroof_ppp_full0 : Value of non-land assets excluding roof (USD) - Full
# asset_total_noroof_ppp_miss0 : Value of non-land assets excluding roof (USD) - Missing
# asset_total_noroof_ppp1 : Value of non-land assets excluding roof (USD)
# asset_livestock_ppp0 : Value of livestock (USD)
# asset_livestock_ppp_full0 : Value of livestock (USD) - Full
# asset_livestock_ppp_miss0 : Value of livestock (USD) - Missing
# asset_livestock_ppp1 : Value of livestock (USD)
# asset_cows_ppp0 : \hspace{0.2cm}Value of cows (USD)
# asset_cows_ppp_full0 : \hspace{0.2cm}Value of cows (USD) - Full
# asset_cows_ppp_miss0 : \hspace{0.2cm}Value of cows (USD) - Missing
# asset_cows_ppp1 : \hspace{0.2cm}Value of cows (USD)
# asset_smalllivestock_ppp0 : \hspace{0.2cm}Value of small livestock (USD)
# asset_smalllivestock_ppp_full0 : \hspace{0.2cm}Value of small livestock (USD) - Full
# asset_smalllivestock_ppp_miss0 : \hspace{0.2cm}Value of small livestock (USD) - Missing
# asset_smalllivestock_ppp1 : \hspace{0.2cm}Value of small livestock (USD)
# asset_birds_ppp0 : \hspace{0.2cm}Value of birds (USD)
# asset_birds_ppp_full0 : \hspace{0.2cm}Value of birds (USD) - Full
# asset_birds_ppp_miss0 : \hspace{0.2cm}Value of birds (USD) - Missing
# asset_birds_ppp1 : \hspace{0.2cm}Value of birds (USD)
# asset_durable_ppp0 : Value of durable goods (USD)
# asset_durable_ppp_full0 : Value of durable goods (USD) - Full
# asset_durable_ppp_miss0 : Value of durable goods (USD) - Missing
# asset_durable_ppp1 : Value of durable goods (USD)
# asset_furniture_ppp0 : \hspace{0.2cm}Value of furniture (USD)
# asset_furniture_ppp_full0 : \hspace{0.2cm}Value of furniture (USD) - Full
# asset_furniture_ppp_miss0 : \hspace{0.2cm}Value of furniture (USD) - Missing
# asset_furniture_ppp1 : \hspace{0.2cm}Value of furniture (USD)
# asset_ag_ppp0 : \hspace{0.2cm}Value of agricultural tools (USD)
# asset_ag_ppp_full0 : \hspace{0.2cm}Value of agricultural tools (USD) - Full
# asset_ag_ppp_miss0 : \hspace{0.2cm}Value of agricultural tools (USD) - Missing
# asset_ag_ppp1 : \hspace{0.2cm}Value of agricultural tools (USD)
# asset_radiotv_ppp0 : \hspace{0.2cm}Value of radio/TV (USD)
# asset_radiotv_ppp_full0 : \hspace{0.2cm}Value of radio/TV (USD) - Full
# asset_radiotv_ppp_miss0 : \hspace{0.2cm}Value of radio/TV (USD) - Missing
# asset_radiotv_ppp1 : \hspace{0.2cm}Value of radio/TV (USD)
# asset_trans_ppp0 : \hspace{0.2cm}Value of bike/motorbike (USD)
# asset_trans_ppp_full0 : \hspace{0.2cm}Value of bike/motorbike (USD) - Full
# asset_trans_ppp_miss0 : \hspace{0.2cm}Value of bike/motorbike (USD) - Missing
# asset_trans_ppp1 : \hspace{0.2cm}Value of bike/motorbike (USD)
# asset_appliance_ppp0 : \hspace{0.2cm}Value of appliances (USD)
# asset_appliance_ppp_full0 : \hspace{0.2cm}Value of appliances (USD) - Full
# asset_appliance_ppp_miss0 : \hspace{0.2cm}Value of appliances (USD) - Missing
# asset_appliance_ppp1 : \hspace{0.2cm}Value of appliances (USD)
# asset_phone_ppp0 : \hspace{0.2cm}Value of cell phone (USD)
# asset_phone_ppp_full0 : \hspace{0.2cm}Value of cell phone (USD) - Full
# asset_phone_ppp_miss0 : \hspace{0.2cm}Value of cell phone (USD) - Missing
# asset_phone_ppp1 : \hspace{0.2cm}Value of cell phone (USD)
# asset_savings_ppp0 : Value of savings (USD)
# asset_savings_ppp_full0 : Value of savings (USD) - Full
# asset_savings_ppp_miss0 : Value of savings (USD) - Missing
# asset_savings_ppp1 : Value of savings (USD)
# asset_land_owned_total0 : Land owned (acres)
# asset_land_owned_total_full0 : Land owned (acres) - Full
# asset_land_owned_total_miss0 : Land owned (acres) - Missing
# asset_land_owned_total1 : Land owned (acres)
# asset_niceroof0 : Has non-thatched roof (dummy)
# asset_niceroof_full0 : Has non-thatched roof (dummy) - Full
# asset_niceroof_miss0 : Has non-thatched roof (dummy) - Missing
# asset_niceroof1 : Has non-thatched roof (dummy)
# asset_lntotal_noroof_ppp0 : Value of non-land assets excluding roof (USD)
# asset_lntotal_noroof_ppp_full0 : Value of non-land assets excluding roof (USD) - Full
# asset_lntotal_noroof_ppp_miss0 : Value of non-land assets excluding roof (USD) - Missing
# asset_lntotal_noroof_ppp1 : Value of non-land assets excluding roof (USD)
# asset_lnlivestock_ppp0 : Value of livestock (USD)
# asset_lnlivestock_ppp_full0 : Value of livestock (USD) - Full
# asset_lnlivestock_ppp_miss0 : Value of livestock (USD) - Missing
# asset_lnlivestock_ppp1 : Value of livestock (USD)
# asset_lncows_ppp0 : \hspace{0.2cm}Value of cows (USD)
# asset_lncows_ppp_full0 : \hspace{0.2cm}Value of cows (USD) - Full
# asset_lncows_ppp_miss0 : \hspace{0.2cm}Value of cows (USD) - Missing
# asset_lncows_ppp1 : \hspace{0.2cm}Value of cows (USD)
# asset_lnsmallstock_ppp0 : \hspace{0.2cm}Value of small livestock (USD)
# asset_lnsmallstock_ppp_full0 : \hspace{0.2cm}Value of small livestock (USD) - Full
# asset_lnsmallstock_ppp_miss0 : \hspace{0.2cm}Value of small livestock (USD) - Missing
# asset_lnsmallstock_ppp1 : \hspace{0.2cm}Value of small livestock (USD)
# asset_lnbirds_ppp0 : \hspace{0.2cm}Value of birds (USD)
# asset_lnbirds_ppp_full0 : \hspace{0.2cm}Value of birds (USD) - Full
# asset_lnbirds_ppp_miss0 : \hspace{0.2cm}Value of birds (USD) - Missing
# asset_lnbirds_ppp1 : \hspace{0.2cm}Value of birds (USD)
# asset_lndurable_ppp0 : Value of durable goods (USD)
# asset_lndurable_ppp_full0 : Value of durable goods (USD) - Full
# asset_lndurable_ppp_miss0 : Value of durable goods (USD) - Missing
# asset_lndurable_ppp1 : Value of durable goods (USD)
# asset_lnfurniture_ppp0 : \hspace{0.2cm}Value of furniture (USD)
# asset_lnfurniture_ppp_full0 : \hspace{0.2cm}Value of furniture (USD) - Full
# asset_lnfurniture_ppp_miss0 : \hspace{0.2cm}Value of furniture (USD) - Missing
# asset_lnfurniture_ppp1 : \hspace{0.2cm}Value of furniture (USD)
# asset_lnag_ppp0 : \hspace{0.2cm}Value of agricultural tools (USD)
# asset_lnag_ppp_full0 : \hspace{0.2cm}Value of agricultural tools (USD) - Full
# asset_lnag_ppp_miss0 : \hspace{0.2cm}Value of agricultural tools (USD) - Missing
# asset_lnag_ppp1 : \hspace{0.2cm}Value of agricultural tools (USD)
# asset_lnradiotv_ppp0 : \hspace{0.2cm}Value of radio/TV (USD)
# asset_lnradiotv_ppp_full0 : \hspace{0.2cm}Value of radio/TV (USD) - Full
# asset_lnradiotv_ppp_miss0 : \hspace{0.2cm}Value of radio/TV (USD) - Missing
# asset_lnradiotv_ppp1 : \hspace{0.2cm}Value of radio/TV (USD)
# asset_lntrans_ppp0 : \hspace{0.2cm}Value of bike/motorbike (USD)
# asset_lntrans_ppp_full0 : \hspace{0.2cm}Value of bike/motorbike (USD) - Full
# asset_lntrans_ppp_miss0 : \hspace{0.2cm}Value of bike/motorbike (USD) - Missing
# asset_lntrans_ppp1 : \hspace{0.2cm}Value of bike/motorbike (USD)
# asset_lnappliance_ppp0 : \hspace{0.2cm}Value of appliances (USD)
# asset_lnappliance_ppp_full0 : \hspace{0.2cm}Value of appliances (USD) - Full
# asset_lnappliance_ppp_miss0 : \hspace{0.2cm}Value of appliances (USD) - Missing
# asset_lnappliance_ppp1 : \hspace{0.2cm}Value of appliances (USD)
# asset_lnphone_ppp0 : \hspace{0.2cm}Value of cell phone (USD)
# asset_lnphone_ppp_full0 : \hspace{0.2cm}Value of cell phone (USD) - Full
# asset_lnphone_ppp_miss0 : \hspace{0.2cm}Value of cell phone (USD) - Missing
# asset_lnphone_ppp1 : \hspace{0.2cm}Value of cell phone (USD)
# asset_lnsavings_ppp0 : Value of savings (USD)
# asset_lnsavings_ppp_full0 : Value of savings (USD) - Full
# asset_lnsavings_ppp_miss0 : Value of savings (USD) - Missing
# asset_lnsavings_ppp1 : Value of savings (USD)
# asset_valroof_ppp0 : Value of iron roof (USD)
# asset_valroof_ppp_full0 : Value of iron roof (USD) - Full
# asset_valroof_ppp_miss0 : Value of iron roof (USD) - Missing
# asset_valroof_ppp1 : Value of iron roof (USD)
# amount_given_mpesa : Amount sent using M-Pesa
# amount_received_mpesa : Amount received using M-Pesa
# amount_saved_mpesa : Amount saved using M-Pesa

# %%
import statsmodels.formula.api as smf

model = smf.ols(
    """
    log_passets_followup
    ~ log_passets_baseline
    + treatXsmall
    + treatXlarge
    + log_passets_baseline:treatXsmall
    + log_passets_baseline:treatXlarge
    """,
    data=rep
).fit(cov_type="HC3")

print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     log_passets_followup   R-squared:                       0.085
# Model:                              OLS   Adj. R-squared:                  0.082
# Method:                   Least Squares   F-statistic:                     22.06
# Date:                  Sun, 30 Aug 2026   Prob (F-statistic):           2.39e-21
# Time:                          11:38:06   Log-Likelihood:                -2769.1
# No. Observations:                  1440   AIC:                             5550.
# Df Residuals:                      1434   BIC:                             5582.
# Df Model:                             5
# Covariance Type:                    HC3
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                            4.1589      0.073     56.716      0.000       4.015       4.303
# log_passets_baseline                 0.0586      0.023      2.579      0.010       0.014       0.103
# treatXsmall                         -1.9730      0.313     -6.309      0.000      -2.586      -1.360
# treatXlarge                         -0.5458      0.422     -1.292      0.196      -1.373       0.282
# log_passets_baseline:treatXsmall     0.4800      0.069      6.929      0.000       0.344       0.616
# log_passets_baseline:treatXlarge     0.2460      0.092      2.682      0.007       0.066       0.426
# ==============================================================================
# Omnibus:                      193.034   Durbin-Watson:                   1.920
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              283.251
# Skew:                          -0.964   Prob(JB):                     3.11e-62
# Kurtosis:                       4.000   Cond. No.                         41.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
